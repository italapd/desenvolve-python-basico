# %% [markdown]
# # Módulo 2 - Aula 2.1 - Variáveis - Exercícios
# **Nome:** Ítala Maria Torres Bersan Sena

# %%
# Q1
# Selecione todos os itens a seguir que contém nomes válidos de variáveis.
# Lembre-se que alguns nomes com estrutura válida são palavras reservadas da linguagem e portanto não podem nomear variáveis.

# a) nome_completo 
# b) quantidade@produtos	
# c) idade	
# d) soma idades 
# e) MediaNotas
# f) _tipo
# g) 2total
# h) lambda

# Preencha o print com as alternativas corretas separadas por espaços em branco.
# Ex: print("a b c")

print("a c e f")

# %%
# Q2
# Dados os scripts a seguir, faça:
# Para os scripts corretos escreva o resultado impresso ao final da execução
# Para os incorretos descreva todos os erros identificados apontando a linha onde cada erro acontece.

# Script 1
x = 10
y = x + 2
print(y - 5)
print("7")

# Script 2
# soma = n1 + n2
# print(soma)
print("Erro: variáveis n1 e n2 não definidas (linha 1)")

# Script 3
a = 10
a = a + 1
print(a)
print("11")

# Script 4
# saldo da conta = 1500
# 0.1 = juros
# print(saldo da conta * juros)
print("Erro: espaços no nome da variável (linha 1) e atribuição inválida (linha 2)")

# %%
# Q3
# Declare três variáveis, num1, num2 e num3, com valores inteiros numéricos de sua escolha.
# Calcule e imprima a média desses três números.
# Utilize a fórmula: (num1 + num2 + num3) / 3.

num1 = 8
num2 = 10
num3 = 6
media = (num1 + num2 + num3) / 3
print("A média é:", media)

# %%
# Q4
# Escreva um script python que:
# - Armazene em uma variável uma velocidade de 90 km/h
# - Calcule e armazene o equivalente em m/s
# - Imprima na tela o resultado

velocidade_kmh = 90
velocidade_ms = velocidade_kmh / 3.6
print("A velocidade em m/s é:", velocidade_ms)

# %%
# Q5
# Escreva um script python que:
# - Armazene o seu nome em uma variável
# - Imprima o texto "Meu nome é:"
# - Imprima a variável com seu nome

nome = "Ítala Maria Torres Bersan Sena"
print("Meu nome é:")
print(nome)
